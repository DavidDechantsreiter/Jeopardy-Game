# %% [markdown]
# # This is Jeopardy!

# %% [markdown]
# In this project I write several functions that investigate a dataset of _Jeopardy!_ questions and answers. Filter the dataset for topics that you're interested in, compute the average difficulty of those questions, and train to become the next Jeopardy champion!

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
jeopardy_data = pd.read_csv('jeopardy.csv')
jeopardy_data.rename(columns = {'Show Number':'show_number', ' Air Date':'air_date', ' Round':'round', ' Category':'category', ' Value':'value', ' Question':'question', ' Answer':'answer'}, inplace = True)
jeopardy_data
# Out:
#         show_number    air_date             round  \
# 0              4680  2004-12-31         Jeopardy!
# 1              4680  2004-12-31         Jeopardy!
# 2              4680  2004-12-31         Jeopardy!
# 3              4680  2004-12-31         Jeopardy!
# 4              4680  2004-12-31         Jeopardy!
# ...             ...         ...               ...
# 216925         4999  2006-05-11  Double Jeopardy!
# 216926         4999  2006-05-11  Double Jeopardy!
# 216927         4999  2006-05-11  Double Jeopardy!
# 216928         4999  2006-05-11  Double Jeopardy!
# 216929         4999  2006-05-11   Final Jeopardy!
#
#                                category  value  \
# 0                               HISTORY   $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2           EVERYBODY TALKS ABOUT IT...   $200
# 3                      THE COMPANY LINE   $200
# 4                   EPITAPHS & TRIBUTES   $200
# ...                                 ...    ...
# 216925                   RIDDLE ME THIS  $2000
# 216926                        "T" BIRDS  $2000
# 216927           AUTHORS IN THEIR YOUTH  $2000
# 216928                       QUOTATIONS  $2000
# 216929                   HISTORIC NAMES   None
#
#                                                                                                                       question  \
# 0                             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1                  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4                     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
# ...                                                                                                                        ...
# 216925                                              This Puccini opera turns on the solution to 3 riddles posed by the heroine
# 216926                 In North America this term is properly applied to only 4 species that are crested, including the tufted
# 216927               In Penny Lane, where this "Hellraiser" grew up, the barber shaves another customer--then flays him alive!
# 216928  From Ft. Sill, Okla. he made the plea, Arizona is my land, my home, my father's land, to which I now ask to... return"
# 216929                 A silent movie title includes the last name of this 18th c. statesman & favorite of Catherine the Great
#
#                                 answer
# 0                           Copernicus
# 1                           Jim Thorpe
# 2                              Arizona
# 3                           McDonald's
# 4                           John Adams
# ...                                ...
# 216925                        Turandot
# 216926                      a titmouse
# 216927                    Clive Barker
# 216928                        Geronimo
# 216929  Grigori Alexandrovich Potemkin
#
# [216930 rows x 7 columns]

# %% [markdown]
# This function filters the dataset for questions that contains all of the words in a list of words. For example, when the list `["King", "England"]` was passed to our function, the function returned a DataFrame of 49 rows. Every row had the strings `"King"` and `"England"` somewhere in its `" Question"`.

# %%
def question_words(data, list_of_words):
    filter = lambda x: all(word in x for word in list_of_words)
    return data.loc[data.question.apply(filter)]

filtered = question_words(jeopardy_data, ['For', 'the', 'life', 'arrest'])
filtered
# Out:
#    show_number    air_date      round category  value  \
# 0         4680  2004-12-31  Jeopardy!  HISTORY  200.0
#
#                                                                                            question  \
# 0  For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
#
#        answer
# 0  Copernicus

# %% [markdown]
# A more robust version of the above function that lowers the strings (essentially normalizing them) to be checked and therefore yields more accurate rersults.

# %%
def question_words2(data, list_of_words):
    filter = lambda x: all(word.lower() in x.lower() for word in list_of_words)
    return data.loc[data.question.apply(filter)]

filtered = question_words2(jeopardy_data, ['King'])
filtered
# Out:
#         show_number    air_date             round                    category  \
# 34             4680  2004-12-31  Double Jeopardy!                 "X"s & "O"s
# 40             4680  2004-12-31  Double Jeopardy!  DR. SEUSS AT THE MULTIPLEX
# 50             4680  2004-12-31  Double Jeopardy!  DR. SEUSS AT THE MULTIPLEX
# 56             5957  2010-07-06         Jeopardy!               GEOGRAPHY "E"
# 72             5957  2010-07-06         Jeopardy!                LET'S BOUNCE
# ...             ...         ...               ...                         ...
# 216777         5070  2006-09-29  Double Jeopardy!             ANCIENT HISTORY
# 216787         5070  2006-09-29  Double Jeopardy!    TALES OF E.T.A. HOFFMANN
# 216789         5070  2006-09-29  Double Jeopardy!             ANCIENT HISTORY
# 216856         5195  2007-03-23  Double Jeopardy!            HAIL TO THE CHEF
# 216916         4999  2006-05-11  Double Jeopardy!                  QUOTATIONS
#
#          value  \
# 34       400.0
# 40      1200.0
# 50      2000.0
# 56       200.0
# 72       600.0
# ...        ...
# 216777   400.0
# 216787  2000.0
# 216789  1200.0
# 216856  1600.0
# 216916  2200.0
#
#                                                                                                                                                                                  question  \
# 34                                                                                  Around 100 A.D. Tacitus wrote a book on how this art of persuasive speaking had declined since Cicero
# 40      <a href="http://www.j-archive.com/media/2004-12-31_DJ_26.mp3">Ripped from today's headlines, he was a turtle king gone mad; Mack was the one good turtle who'd bring him down</a>
# 50                    <a href="http://www.j-archive.com/media/2004-12-31_DJ_24.mp3">"500 Hats"... 500 ways to die.  On July 4th, this young boy will defy a king... & become a legend</a>
# 56                                                                                                                                         It's the largest kingdom in the United Kingdom
# 72                                                                                            In this kid's game, you bounce a small rubber ball while picking up 6-pronged metal objects
# ...                                                                                                                                                                                   ...
# 216777                                                                 The first one of these tombs was built about 2650 B.C. by Imhotep for King Zoser & rose about 200 feet using steps
# 216787                                                                                   A Hoffmann tale title lost the words "And The Mouse King" when it became this Tchaikovsky ballet
# 216789                                                                                 This kingdom of England grew from 2 settlements, one founded around 495 by Cerdic & his son Cynric
# 216856                                        You can cook like <a href="http://www.j-archive.com/media/2007-03-23_DJ_24.jpg" target="_blank">this</a> man who wrote "The Joy of Wokking"
# 216916                                                                                                          Oscar Wilde called this 4-letter word "the curse of the drinking classes"
#
#                                    answer
# 34                                oratory
# 40                                 Yertle
# 50                    Bartholomew Cubbins
# 56                                England
# 72                                  jacks
# ...                                   ...
# 216777  a pyramid (the pyramids accepted)
# 216787                     The Nutcracker
# 216789                             Wessex
# 216856                       (Martin) Yan
# 216916                               work
#
# [7409 rows x 7 columns]

# %% [markdown]
# Next I cleaned the value column, as its values were strings and I wanted to convert it to numerical values in order to be able to use statsitcs like mean and max/min on this column.

# %%
value_to_float_lambda = lambda row: float(row.value.strip('$').replace(',', '')) if row.value != 'None' else 0
jeopardy_data['value'] = jeopardy_data.apply(value_to_float_lambda, axis = 1)

# %%
#Now I can use my filter function from earlier in order to see how the mean behaves with different words
print(jeopardy_data.value.mean())
question_w_king = question_words2(jeopardy_data, ['King'])
print(question_w_king.value.mean())
# Out:
# 739.9884755451067
# 771.8833850722094

# %% [markdown]
# This next function returns the count of unique answers to all of the questions in a dataset. For example, after filtering the entire dataset to only questions containing the word `"King"`, we could then find all of the unique answers to those questions.

# %%
def unique_answers_for_filtered_questions(data, filter_words):
    filtered_data = question_words(data, filter_words)
    all_answers = filtered_data.answer.unique()
    for answer in all_answers:
        temp_fram = filtered_data[filtered_data.answer == answer]
        print(answer, len(temp_fram))
        
        
def short(data):
    return data.answer.value_counts()

#unique_answers_for_filtered_questions(jeopardy_data, ['King'])
short(filtered)

#The answer "Henry VIII" appeared 55 times and was the most common answer.
# Out:
# Henry VIII                   55
# Solomon                      35
# Richard III                  33
# Louis XIV                    31
# David                        30
#                              ..
# cardiac (in card I acted)     1
# Henderson                     1
# Computer                      1
# Indians                       1
# work                          1
# Name: answer, Length: 5268, dtype: int64

# %% [markdown]
# 6. Explore from here! This is an incredibly rich dataset, and there are so many interesting things to discover. There are a few columns that we haven't even started looking at yet. Here are some ideas on ways to continue working with this data:
#
#  * Investigate the ways in which questions change over time by filtering by the date. How many questions from the 90s use the word `"Computer"` compared to questions from the 2000s?
#  * Is there a connection between the round and the category? Are you more likely to find certain categories, like `"Literature"` in Single Jeopardy or Double Jeopardy?
#  * Build a system to quiz yourself. Grab random questions, and use the <a href="https://docs.python.org/3/library/functions.html#input">input</a> function to get a response from the user. Check to see if that response was right or wrong.

# %%
jeopardy_data

air_date1 = jeopardy_data.air_date[0][0:4]
print(air_date1)

def words_in_time(data, words, years):
    years_str = [str(year) for year in years]
    print(years_str)
    range_frame_columns = {'show_number': [], 'air_date': [], 'round': [], 'category': [], 'value': [], 'question': [], 'answer': []}
    range_frame = pd.DataFrame(range_frame_columns)
    for year in years_str:
        year_lambda = lambda row: row['air_date'][0:4] == year
        filtered_year = data[data.apply(year_lambda, axis = 1)]
        filtered_both = question_words(filtered_year, words)
        range_frame = pd.concat([range_frame, filtered_both])
    return range_frame

words_in_time(jeopardy_data, [' Computer '], range(1991, 2000))
# Out:
# 2004
# ['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999']
#         show_number    air_date             round  \
# 149993       1525.0  1991-03-29         Jeopardy!
# 143917       2038.0  1993-06-16  Double Jeopardy!
# 143069       2578.0  1995-11-15  Double Jeopardy!
# 186728       2543.0  1995-09-27  Double Jeopardy!
# 191881       2840.0  1996-12-27         Jeopardy!
# 191929       2815.0  1996-11-22         Jeopardy!
# 209897       2676.0  1996-04-01         Jeopardy!
# 22502        2874.0  1997-02-13         Jeopardy!
# 51059        2990.0  1997-09-05         Jeopardy!
# 52516        2912.0  1997-04-08  Double Jeopardy!
# 71864        2921.0  1997-04-21         Jeopardy!
# 78920        3032.0  1997-11-04  Double Jeopardy!
# 132840       2953.0  1997-06-04  Double Jeopardy!
# 158912       2966.0  1997-06-23  Double Jeopardy!
# 180954       2870.0  1997-02-07         Jeopardy!
# 180966       2870.0  1997-02-07         Jeopardy!
# 196362       2958.0  1997-06-11         Jeopardy!
# 205304       3070.0  1997-12-26  Double Jeopardy!
# 212789       2871.0  1997-02-10  Double Jeopardy!
# 216527       3038.0  1997-11-12         Jeopardy!
# 216533       3038.0  1997-11-12         Jeopardy!
# 20837        3118.0  1998-03-04         Jeopardy!
# 30404        3178.0  1998-05-27  Double Jeopardy!
# 33848        3243.0  1998-10-14         Jeopardy!
# 47538        3164.0  1998-05-07         Jeopardy!
# 47544        3164.0  1998-05-07         Jeopardy!
# 74311        3167.0  1998-05-12  Double Jeopardy!
# 97268        3294.0  1998-12-24         Jeopardy!
# 120072       3119.0  1998-03-05  Double Jeopardy!
# 120084       3119.0  1998-03-05  Double Jeopardy!
# 120326       3210.0  1998-07-10  Double Jeopardy!
# 174325       3180.0  1998-05-29  Double Jeopardy!
# 206907       3260.0  1998-11-06  Double Jeopardy!
# 211882       3224.0  1998-09-17  Double Jeopardy!
# 5077         3480.0  1999-10-22  Double Jeopardy!
# 26354        3494.0  1999-11-11  Double Jeopardy!
# 32162        3463.0  1999-09-29  Double Jeopardy!
# 36817        3488.0  1999-11-03         Jeopardy!
# 37064        3375.0  1999-04-16         Jeopardy!
# 42462        3487.0  1999-11-02  Double Jeopardy!
# 42468        3487.0  1999-11-02  Double Jeopardy!
# 78001        3466.0  1999-10-04         Jeopardy!
# 86813        3377.0  1999-04-20         Jeopardy!
# 90991        3349.0  1999-03-11         Jeopardy!
# 117126       3474.0  1999-10-14         Jeopardy!
# 131058       3448.0  1999-09-08  Double Jeopardy!
# 131082       3448.0  1999-09-08  Double Jeopardy!
# 136011       3497.0  1999-11-16  Double Jeopardy!
# 148151       3412.0  1999-06-08  Double Jeopardy!
# 154056       3337.0  1999-02-23  Double Jeopardy!
# 170148       3348.0  1999-03-10         Jeopardy!
# 172646       3378.0  1999-04-21  Double Jeopardy!
# 179068       3395.0  1999-05-14         Jeopardy!
# 193712       3392.0  1999-05-11         Jeopardy!
# 197458       3394.0  1999-05-13  Double Jeopardy!
#
#                               category   value  \
# 149993             BUSINESS & INDUSTRY   100.0
# 143917                 U.S. GOVERNMENT   800.0
# 143069                            1995   400.0
# 186728                           WOMEN   600.0
# 191881               CORPORATE AMERICA   500.0
# 191929             BUSINESS & INDUSTRY   300.0
# 209897                APRIL FOOLS' DAY   200.0
# 22502              BUSINESS & INDUSTRY   200.0
# 51059                 BORN IN THE '60S   300.0
# 52516                   CONTEMPORARIES   600.0
# 71864                   LETTER PERFECT   400.0
# 78920             SCHWARZENEGGER FILMS   400.0
# 132840                       POTPOURRI   400.0
# 158912             BUSINESS & INDUSTRY   800.0
# 180954                       COMPUTERS   300.0
# 180966                       COMPUTERS   500.0
# 196362                  4-LETTER WORDS   200.0
# 205304              MILESTONES IN MATH   200.0
# 212789                          ESSAYS   800.0
# 216527                     COMPUTERESE   400.0
# 216533                     COMPUTERESE   500.0
# 20837                        GO TO "H"   200.0
# 30404               1997 BUSINESS NEWS   200.0
# 33848                  GUYS NAMED GARY   500.0
# 47538              COMPUTER CHARACTERS   400.0
# 47544              COMPUTER CHARACTERS   500.0
# 74311                  WORD PROCESSING   800.0
# 97268             STORES WITHOUT WALLS   500.0
# 120072                     ELECTRONICS   200.0
# 120084                     ELECTRONICS   600.0
# 120326                       OXYMORONS   600.0
# 174325                SCIENCE & NATURE  1000.0
# 206907                  4-LETTER WORDS   600.0
# 211882                    WORD ORIGINS   200.0
# 5077           19th CENTURY LITERATURE   500.0
# 26354         TECH BUSINESS & INDUSTRY  1000.0
# 32162                    ABBREVIATIONS  1000.0
# 36817                      COMPUTERAMA   200.0
# 37064                         PC WORLD   300.0
# 42462                COMPUTER LITERACY   600.0
# 42468                COMPUTER LITERACY   800.0
# 78001   THINGS I LEARNED AT THE MOVIES   400.0
# 86813                       TECHNOLOGY   500.0
# 90991                           AD AGE   100.0
# 117126                 YOU OUGHTA KNOW   300.0
# 131058                       COMPUTERS   200.0
# 131082                       COMPUTERS  1000.0
# 136011                       POTPOURRI   600.0
# 148151                     THE Y2K BUG   600.0
# 154056            20th CENTURY AMERICA   400.0
# 170148                            "IN"   200.0
# 172646                            "FI"  1000.0
# 179068           ROGER EBERT ON MOVIES   500.0
# 193712                         WEALTHY   500.0
# 197458                    FAMOUS FOLKS   200.0
#
#                                                                                                                   question  \
# 149993                        This biggest computer company is biggest also among companies in philanthropic contributions
# 143917                                        This agency, the GSA, operates the Federal Communications & Computer Systems
# 143069                               In June, Lotus Development Corporation agreed to be taken over by this computer giant
# 186728                          Grace Murray Hopper, who helped develop COBOL, also coined this term for a computer glitch
# 191881              Hoover's Handbook says this South Dakota mail-order computer firm is the USA's fastest-growing company
# 191929                                     In 1993 Louis V. Gerstner became the first outsider to head this computer giant
# 209897                                        The "core" of this computer company goes back to its founding, April 1, 1976
# 22502                                         This company's new computer products include the Aptiva S & the Thinkpad 560
# 51059                       In 1996, he beat a chess-playing IBM computer called Deep Blue; in 1997 the tables were turned
# 52516          While Charles Babbage was trying to build a computer in the 1820s, this Scot invented what would be a "Mac"
# 71864                                 This computer chip is named for the type of TV programming parents may want to block
# 78920       Wife Jamie Lee Curtis thought hubby Arnold was a computer salesman instead of a superspy in this 1994 thriller
# 132840                                                                This computer maker's NASDAQ symbol is AAPL, not MAC
# 158912                                       This computer company's new Presario 4402 features an infrared remote control
# 180954                                                    This company describes its pentium chip as "The Computer Inside"
# 180966                This North Sioux City, S.D. mail order computer maker issues a MasterCard with a cowhide print on it
# 196362                                               On a computer screen this small picture represents a specific program
# 205304                           In the '40s Harvard's Howard Aiken developed the Mark I computer with this company's help
# 212789                            This humorist's collection of essays "In Cyberspace" is formatted like a computer manual
# 216527                    Like a waiter, a network computer might say "I'll be your" this & store files or manage printers
# 216533                                    "Strap" once completed this word meaning to start a computer by loading software
# 20837                        At best, it's a computer enthusiast; at worst, it's one who illegally taps into your computer
# 30404                  In Jan. some said this computer chip maker would become the world's most profitable company by 1999
# 33848                                                     A Russian chess grandmaster, this man lost to a computer in 1997
# 47538                                               TV series set inside a computer that features the characters seen here
# 47544                                                1 of the 2 computer games that feature the clay man Klaymen seen here
# 74311                                Term for the printer or margins your computer is set for unless you tell it otherwise
# 97268                        This computer company founded by a man named Michael does $6 million of business online a day
# 120072                    This device allows a computer to connect to phone lines & access other computers on the internet
# 120084                                                          This element is the main ingredient of most computer chips
# 120326                                         Abbreviated VR, it was coined by computer scientist & musician Jaron Lanier
# 174325                      Announced on February 14, 1946, this first electronic digital computer had 18,000 vacuum tubes
# 206907                                                   A computer ready to receive information over a modem is "on" this
# 211882                       Derived from the Greek for "throw", you can throw a floppy one into a computer & store a file
# 5077                Edward Bellamy's 1888 book "Looking Backward" sends a man to this year & doesn't mention computer bugs
# 26354                  Linus Torvalds developed this upstart computer operating system that's usually available at no cost
# 32162                                                                          A computer designer's goal:              AI
# 36817                                                     The computer visual seen here is known by this "restaurant" term
# 37064                              To take fleas off your dog, or to detect, locate & correct errors in a computer program
# 42462                                        This psychotic computer is repaired in Arthur C. Clarke's "2010: Odyssey Two"
# 42468                       A computer commits suicide after talking to Marvin the Robot in this first Douglas Adams novel
# 78001                           10-year-old kids are the most expert at this activity, illicitly entering computer systems
# 86813               On August 12, 1981 the world saw the first IBM personal computer using this Microsoft operating system
# 90991              Bob Dylan, Pablo Picasso & Albert Einstein "Think Different" according to ads for this computer company
# 117126                       Hungarian-born Andrew Grove rose "inside" this computer chip company & made it dominant today
# 131058                                    Apple made a computer called Lisa before they introduced this famous one in 1984
# 131082                                    The number of MHz, which stands for this, tells you how fast a computer you have
# 136011                                If your computer has this kind of "base", you should know it's the plural of "datum"
# 148151                         The bug partly stems from 6-digit dates in this 1960s "business-oriented" computer language
# 154056            On April 1, 1976 2 engineers with $1,300 in capital began this computer company in Cupertino, California
# 170148                                                                 The initials of computer giant "IBM" stand for this
# 172646                         In computer security, this device blocks unauthorized access to a LAN, a local area network
# 179068           This 1982 Disney film in which a man gets lost in a computer was part of my 1999 Overlooked Film Festival
# 193712  Prince Alwaleed Bin Talal is the biggest individual shareholder in Apple Computer & this amusement park near Paris
# 197458         Billionaire business giant who said, "In the personal computer industry, innovation is the path to success"
#
#                                                       answer
# 149993                                                   IBM
# 143917                       General Services Administration
# 143069                                                   IBM
# 186728                                                 a bug
# 191881                                          Gateway 2000
# 191929                                                   IBM
# 209897                                        Apple Computer
# 22502                                                    IBM
# 51059                                         Garry Kasparov
# 52516                                       Charles McIntosh
# 71864                                                 V-Chip
# 78920                                              True Lies
# 132840                                                 Apple
# 158912                                                Compaq
# 180954                                                 Intel
# 180966                                          Gateway 2000
# 196362                                               an icon
# 205304                                                   IBM
# 212789                                            Dave Barry
# 216527                                                Server
# 216533                                                  Boot
# 20837                                                 Hacker
# 30404                                                  Intel
# 33848                                         Garry Kasparov
# 47538                                                 ReBoot
# 47544                      "The Neverhood" or "Skullmonkeys"
# 74311                                                Default
# 97268                                                   Dell
# 120072                                                 Modem
# 120084                                               Silicon
# 120326                                       Virtual reality
# 174325  ENIAC (Electronic Numerical Integrator And Computer)
# 206907                                                  line
# 211882                                                a disk
# 5077                                                    2000
# 26354                                                  Linux
# 32162                                Artificial Intelligence
# 36817                                                   Menu
# 37064                                                  Debug
# 42462                                                    HAL
# 42468                 "The Hitchhiker's Guide to the Galaxy"
# 78001                                                Hacking
# 86813                                                 MS-DOS
# 90991                                                  Apple
# 117126                                                 Intel
# 131058                                             Macintosh
# 131082                                             Megahertz
# 136011                                                  data
# 148151                                                 COBOL
# 154056                                                 Apple
# 170148                       International Business Machines
# 172646                                              Firewall
# 179068                                                  Tron
# 193712                                           Euro Disney
# 197458                                            Bill Gates

# %% [markdown]
# This function filters the data based on the years provided and returns a pandas DataFrame containing the filtered data.

# %%
def filter_in_time(data, years):
    years_str = [str(year) for year in years]
    range_frame_columns = {'show_number': [], 'air_date': [], 'round': [], 'category': [], 'value': [], 'question': [], 'answer': []}
    range_frame = pd.DataFrame(range_frame_columns)
    for year in years_str:
        year_lambda = lambda row: row['air_date'][0:4] == year
        filtered_year = data[data.apply(year_lambda, axis = 1)]
        range_frame = pd.concat([range_frame, filtered_year])
    return range_frame
        
recent_jp = filter_in_time(jeopardy_data, range(2000, 2014)).reset_index()
recent_jp
# Out:
#          index  show_number    air_date             round  \
# 0          117       3751.0  2000-12-18         Jeopardy!
# 1          118       3751.0  2000-12-18         Jeopardy!
# 2          119       3751.0  2000-12-18         Jeopardy!
# 3          120       3751.0  2000-12-18         Jeopardy!
# 4          121       3751.0  2000-12-18         Jeopardy!
# ...        ...          ...         ...               ...
# 152072  192273       6292.0  2012-01-17  Double Jeopardy!
# 152073  192274       6292.0  2012-01-17  Double Jeopardy!
# 152074  192275       6292.0  2012-01-17  Double Jeopardy!
# 152075  192276       6292.0  2012-01-17  Double Jeopardy!
# 152076  192277       6292.0  2012-01-17   Final Jeopardy!
#
#                                         category   value  \
# 0                         ROYAL FEMALE NICKNAMES   100.0
# 1                              TV ACTORS & ROLES   100.0
# 2                               TRAVEL & TOURISM   100.0
# 3                                       "I" LADS   100.0
# 4                                      FOREWORDS   100.0
# ...                                          ...     ...
# 152072  I PLAYED A DOCTOR & SOME OTHER GUY ON TV  2000.0
# 152073                           CLASSICAL MUSIC  2000.0
# 152074                    POSSESSIVE BOOK TITLES  2000.0
# 152075                                "TRI" TIPS  2000.0
# 152076                           U.S. POPULATION     0.0
#
#                                                                                                                                 question  \
# 0                                                                           Prime Minister Tony Blair dubbed her "The People's Princess"
# 1                        Once Tommy Mullaney on "L.A. Law", John Spencer now plays White House chief of staff Leo McGarry on this series
# 2                                                      The Cinderella Castle Mystery Tour is a highlight of this Asian city's Disneyland
# 3                                                 This punk rock hitmaker heard here has had numerous hits on both sides of the Atlantic
# 4                     "Conrad begins (and ends) Marlow's journey... on the Thames, on the yawl, Nellie", says the foreword to this novel
# ...                                                                                                                                  ...
# 152072                                                                       Marcus Welby & Jim Anderson (the "Father" who "Knows Best")
# 152073                                   This composer of Armenian heritage is best known for the "Sabre Dance" from his ballet "Gayane"
# 152074                                                                                    Kim Edwards: "The ____ ____'s Daughter" (2005)
# 152075                                                                     This was an ancient Roman warship with multiple tiers of oars
# 152076  Between 2000 & 2010 these 2 states that border each other led the nation in highest percentage of population increase, 35% & 25%
#
#                               answer
# 0                     Princess Diana
# 1                      The West Wing
# 2                              Tokyo
# 3                         Billy Idol
# 4                  Heart of Darkness
# ...                              ...
# 152072                  Robert Young
# 152073           (Aram) Khachaturian
# 152074  The Memory Keeper's Daughter
# 152075                     a trireme
# 152076            Arizona and Nevada
#
# [152077 rows x 8 columns]

# %%
money_counter = 2000

# %%
# This is an attempt to calcualte a ratio of correctness, a metric that could be used to determine if the 
# user meant the right thing, but had a typo or forgot an article or something of the sorts.
# Currently the jeopardy game only works if the entire string is correct. If the answer is "a flush" and the user
# put "flush" the answer will be wrong. The below function was meant to get rid of this issue, however 
# it never really got there :(

def calculate_correctness_ratio(answer, real_answer):
    correct_counter = 0
    total_counter = min(len(answer), len(real_answer))
    
    # Iterate through each character in the shortest answer string
    for i in range(total_counter):
        # Check if the current character is correct and has correct neighbors
        if answer[i] == real_answer[i] and i > 0 and i < total_counter - 1:
            if answer[i - 1] == real_answer[i - 1] and answer[i + 1] == real_answer[i + 1]:
                correct_counter += 1
    
    # Calculate the ratio of correctness
    if total_counter > 0:
        correctness_ratio = correct_counter / len(real_answer)
    else:
        correctness_ratio = 0.0  # To handle the case where both answers are empty
    
    return correctness_ratio

# Example usage
real_answer = "prologue"
user_answer = "prologue"
ratio = calculate_correctness_ratio(user_answer, real_answer)
print(f"Ratio of correctness: {ratio}")

cans = recent_jp[recent_jp.question == "An epilogue is found at the end of a book; this opposite term is a short section at the beginning of a book"]
cans
# Out:
# Ratio of correctness: 0.75
#        index  show_number    air_date             round           category  \
# 58310  51448       4706.0  2005-02-07  Double Jeopardy!  OPPOSITES ATTRACT
#
#        value  \
# 58310  800.0
#
#                                                                                                           question  \
# 58310  An epilogue is found at the end of a book; this opposite term is a short section at the beginning of a book
#
#            answer
# 58310  a prologue

# %% [markdown]
# The function below is a jeopardy game that makes use of the dataset. Rules are listed below.

# %%
import random as rdm



def play_jeopardy(data):
    global money_counter
    rand_jeop = data.iloc[rdm.randint(1, len(data))]
    print(rand_jeop.question + '\n')
    user_answer = input("Enter your answer: ")
    if(user_answer.lower() in 'skip'):
        print('Question skipped')
        print("The correct answer was: " + rand_jeop.answer)
        money_counter -= 20
    elif(user_answer.lower() == "give context"):
        print("category: " + rand_jeop.category)
        print("Air date: " + rand_jeop.air_date)
        print("value: " + str(rand_jeop.value))
        user_answer_after_context = input("Enter your answer using the context: ")
        if(user_answer_after_context.lower() in rand_jeop.answer.lower()):
            print("OOOOOHHH yeah baby that is the correct answer! The correct answer was: " + rand_jeop.answer)
            print("you won: $"+str(rand_jeop.value/2) + "!")
            money_counter += rand_jeop.value/2
        elif(user_answer_after_context.lower() in 'skip'):
            print('Question skipped')
            print("The correct answer was: " + rand_jeop.answer)
            money_counter -= 20
        else:
            print("Tough luck, you lose all your money! The correct answer was: " + rand_jeop.answer)
            money_counter -= 150
            
    elif(user_answer.lower() in rand_jeop.answer.lower()):
        print("OOOOOHHH yeah baby that is the correct answer! The correct answer was: " + rand_jeop.answer)
        print("you won: $"+str(rand_jeop.value) + "!")
        money_counter += rand_jeop.value
    else:
        print("Tough luck, you lose all your money! The correct answer was: " + rand_jeop.answer)
        money_counter -= 100
        

#An epilogue is found at the end of a book; this opposite term is a short section at the beginning of a book

# %% [markdown]
# PLAY HERE:
#
# Rules:
# This game is about mainting your original money (2000$) and making as much as you can. The game ends when the player decides to stop playing or the money goes to 0. There are some special commands that the player can use in order to win:
#
# - 'skip': skips the question (-20$)
#
# - 'give context': reveals category, air data and value of question (halves the value to be gained if won, -150$ if still wrong answer)
#
#
# - wrong answer: -100$
# - right answer: + the value of the question

# %%
play_jeopardy(recent_jp)
print("current money: " + str(money_counter))
# Out:
# In poker, 3 & 5 of hearts, 10 of clubs, jack of hearts, king of hearts is called a busted this
#
# Enter your answer: give context
# category: HODGEPODGE
# Air date: 2009-02-09
# value: 400.0
# Enter your answer using the context: skip
# Question skipped
# The correct answer was: a flush
# current money: 2000
